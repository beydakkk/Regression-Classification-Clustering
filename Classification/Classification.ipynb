# %% [markdown]
# # <font color = green> CLASSIFICATION

# %%
### Import libraries
import pandas as pd
pd.set_option("display.max_columns",100)

# %%
import warnings
warnings.simplefilter("ignore")

# %%
### Import Data
df = pd.read_csv("hr_data.csv")
### İşten ayrılıp ayrılmayacağını tahmin eden model

# %% [markdown]
# ### <font color=red> EDA - Exploratory Data Analysis

# %%
df.head()
# Out:
#    Age     BusinessTravel  DailyRate              Department  \
# 0   41      Travel_Rarely       1102                   Sales
# 1   49  Travel_Frequently        279  Research & Development
# 2   37      Travel_Rarely       1373  Research & Development
# 3   33  Travel_Frequently       1392  Research & Development
# 4   27      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %%
df.sample(3)
# Out:
#      Age     BusinessTravel  DailyRate              Department  \
# 165   50      Travel_Rarely       1452  Research & Development
# 569   36         Non-Travel       1434                   Sales
# 544   47  Travel_Frequently        217                   Sales
#
#      DistanceFromHome  Education EducationField  EmployeeCount  \
# 165                11          3  Life Sciences              1
# 569                 8          4  Life Sciences              1
# 544                 3          3        Medical              1
#
#      EmployeeNumber  EnvironmentSatisfaction  Gender  HourlyRate  \
# 165             226                        3  Female          53
# 569             789                        1    Male          76
# 544             746                        4  Female          49
#
#      JobInvolvement  JobLevel          JobRole  JobSatisfaction  \
# 165               3         5          Manager                2
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   BusinessTravel            1470 non-null   object
#  2   DailyRate                 1470 non-null   int64
#  3   Department                1470 non-null   object
#  4   DistanceFromHome          1470 non-null   int64
#  5   Education                 1470 non-null   int64
#  6   EducationField            1470 non-null   object
#  7   EmployeeCount             1470 non-null   int64
#  8   EmployeeNumber            1470 non-null   int64
#  9   EnvironmentSatisfaction   1470 non-null   int64
#  10  Gender                    1470 non-null   object
#  11  HourlyRate                1470 non-null   int64
#  12  JobInvolvement            1470 non-null   int64
#  13  JobLevel                  1470 non-null   int64
# ...

# %%
df.isnull().sum()
# Out:
# Age                           0
# BusinessTravel                0
# DailyRate                     0
# Department                    0
# DistanceFromHome              0
# Education                     0
# EducationField                0
# EmployeeCount                 0
# EmployeeNumber                0
# EnvironmentSatisfaction       0
# Gender                        0
# HourlyRate                    0
# JobInvolvement                0
# JobLevel                      0
# JobRole                       0
# JobSatisfaction               0
# MaritalStatus                 0
# MonthlyIncome                 0
# MonthlyRate                   0
# NumCompaniesWorked            0
# Over18                        0
# OverTime                      0
# PercentSalaryHike             0
# PerformanceRating             0
# RelationshipSatisfaction      0
# StandardHours                 0
# StockOptionLevel              0
# TotalWorkingYears             0
# TrainingTimesLastYear         0
# ...

# %%
df.corr()
# Out:
#                                Age  DailyRate  DistanceFromHome  Education  \
# Age                       1.000000   0.010661         -0.001686   0.208034
# DailyRate                 0.010661   1.000000         -0.004985  -0.016806
# DistanceFromHome         -0.001686  -0.004985          1.000000   0.021042
# Education                 0.208034  -0.016806          0.021042   1.000000
# EmployeeCount                  NaN        NaN               NaN        NaN
# EmployeeNumber           -0.010145  -0.050990          0.032916   0.042070
# EnvironmentSatisfaction   0.010146   0.018355         -0.016075  -0.027128
# HourlyRate                0.024287   0.023381          0.031131   0.016775
# JobInvolvement            0.029820   0.046135          0.008783   0.042438
# JobLevel                  0.509604   0.002966          0.005303   0.101589
# JobSatisfaction          -0.004892   0.030571         -0.003669  -0.011296
# ...

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(11,11))
sns.heatmap(df.corr());
#üzerinde sayıları görmek istersek sns.heatmap(df.corr(),annot=True);

# %%
df.columns
# Out:
# Index(['Age', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeCount', 'EmployeeNumber',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'Over18',
#        'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager', 'Attrition'],
#       dtype='object')

# %%
df.shape
# Out:
# (1470, 35)

# %%
df["Attrition"].value_counts()
# Out:
# No     1020
# Yes     185
# Name: Attrition, dtype: int64

# %%
#sns.pairplot(df)

# %%
sns.countplot(x=df["Attrition"]);

# %%
sns.countplot(x=df["Education"]);

# %%
sns.countplot(x=df["Education"]);

# %% [markdown]
# ### <font color=red>Feature Engineering

# %%
df['Attrition']
# Out:
# 0       Yes
# 1        No
# 2       Yes
# 3        No
# 4        No
#        ...
# 1465    NaN
# 1466     No
# 1467     No
# 1468     No
# 1469     No
# Name: Attrition, Length: 1470, dtype: object

# %%
# Yes -> 1 No -> 0 yapmak için ---> DICTIONARY
dict = {"Yes":1,"No":0}

# %%
df["Attrition"] = df["Attrition"].map(dict)

# %%
df["Attrition"]
# Out:
# 0       1.0
# 1       0.0
# 2       1.0
# 3       0.0
# 4       0.0
#        ...
# 1465    NaN
# 1466    0.0
# 1467    0.0
# 1468    0.0
# 1469    0.0
# Name: Attrition, Length: 1470, dtype: float64

# %%
empty = df[df["Attrition"].isnull()]

# %%
empty
# Out:
#       Age     BusinessTravel  DailyRate              Department  \
# 367    50      Travel_Rarely       1046  Research & Development
# 368    40      Travel_Rarely        575                   Sales
# 369    31      Travel_Rarely        408  Research & Development
# 370    21      Travel_Rarely        156                   Sales
# 371    29      Travel_Rarely       1283  Research & Development
# ...   ...                ...        ...                     ...
# 1461   50      Travel_Rarely        410                   Sales
# 1462   39      Travel_Rarely        722                   Sales
# 1463   31         Non-Travel        325  Research & Development
# 1464   26      Travel_Rarely       1167                   Sales
# 1465   36  Travel_Frequently        884  Research & Development
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  \
# 367                 10          3  Technical Degree              1
# ...

# %%
filled =df[df["Attrition"].notnull()]

# %%
filled
# Out:
#       Age     BusinessTravel  DailyRate              Department  \
# 0      41      Travel_Rarely       1102                   Sales
# 1      49  Travel_Frequently        279  Research & Development
# 2      37      Travel_Rarely       1373  Research & Development
# 3      33  Travel_Frequently       1392  Research & Development
# 4      27      Travel_Rarely        591  Research & Development
# ...   ...                ...        ...                     ...
# 1439   36      Travel_Rarely        557                   Sales
# 1466   39      Travel_Rarely        613  Research & Development
# 1467   27      Travel_Rarely        155  Research & Development
# 1468   49  Travel_Frequently       1023                   Sales
# 1469   34      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                    1          2  Life Sciences              1
# 1                    8          1  Life Sciences              1
# ...

# %%
x = filled.drop("Attrition",axis=1) #axis=1 sütun axis=0 satır siler.  drop-> silmek
y=filled["Attrition"]

# %%
x
# Out:
#       Age     BusinessTravel  DailyRate              Department  \
# 0      41      Travel_Rarely       1102                   Sales
# 1      49  Travel_Frequently        279  Research & Development
# 2      37      Travel_Rarely       1373  Research & Development
# 3      33  Travel_Frequently       1392  Research & Development
# 4      27      Travel_Rarely        591  Research & Development
# ...   ...                ...        ...                     ...
# 1439   36      Travel_Rarely        557                   Sales
# 1466   39      Travel_Rarely        613  Research & Development
# 1467   27      Travel_Rarely        155  Research & Development
# 1468   49  Travel_Frequently       1023                   Sales
# 1469   34      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                    1          2  Life Sciences              1
# 1                    8          1  Life Sciences              1
# ...

# %%
y
# Out:
# 0       1.0
# 1       0.0
# 2       1.0
# 3       0.0
# 4       0.0
#        ...
# 1439    0.0
# 1466    0.0
# 1467    0.0
# 1468    0.0
# 1469    0.0
# Name: Attrition, Length: 1205, dtype: float64

# %%
x.sample(5)
# Out:
#       Age     BusinessTravel  DailyRate              Department  \
# 194    45         Non-Travel       1195  Research & Development
# 960    41  Travel_Frequently       1018                   Sales
# 170    27      Travel_Rarely       1157  Research & Development
# 823    29  Travel_Frequently        490  Research & Development
# 1390   28      Travel_Rarely       1404  Research & Development
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  \
# 194                  2          2           Medical              1
# 960                  1          3         Marketing              1
# 170                 17          3  Technical Degree              1
# 823                 10          3     Life Sciences              1
# 1390                17          3  Technical Degree              1
#
#       EmployeeNumber  EnvironmentSatisfaction  Gender  HourlyRate  \
# 194              264                        1    Male          65
# ...

# %%
x.shape
# Out:
# (1205, 34)

# %%
x["BusinessTravel"].value_counts()
# Out:
# Travel_Rarely        845
# Travel_Frequently    235
# Non-Travel           125
# Name: BusinessTravel, dtype: int64

# %%
x = pd.get_dummies(x,drop_first=True)

# %%
x.head()
# Out:
#    Age  DailyRate  DistanceFromHome  Education  EmployeeCount  EmployeeNumber  \
# 0   41       1102                 1          2              1               1
# 1   49        279                 8          1              1               2
# 2   37       1373                 2          2              1               4
# 3   33       1392                 3          4              1               5
# 4   27        591                 2          1              1               7
#
#    EnvironmentSatisfaction  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2          94               3         2
# 1                        3          61               2         2
# 2                        4          92               2         1
# 3                        4          56               3         1
# 4                        1          40               3         1
#
#    JobSatisfaction  MaritalStatus  MonthlyIncome  MonthlyRate  \
# ...

# %%
x.shape
# Out:
# (1205, 46)

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import BernoulliNB

G = GaussianNB()
B = BernoulliNB()

# %%
G.fit(x,y)
# Out:
# GaussianNB()

# %%
B.fit(x,y)
# Out:
# BernoulliNB()

# %%
prediction1 = G.predict(x)
prediction2 = B.predict(x)

# %% [markdown]
# Classification'da bakılacklar:
# 1. Accuracy
# 1. Precision
# 1. Recall
# 1. f1 score
# 1. confusion matrix

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
accuracy_score(prediction1,y)
# Out:
# 0.808298755186722

# %%
confusion_matrix(prediction1,y)  # 849 + 126 doğrular    59 + 172 yanlışlar
# Out:
# array([[848,  59],
#        [172, 126]], dtype=int64)

# %%
print(classification_report(prediction1,y))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.83      0.93      0.88       907
#          1.0       0.68      0.42      0.52       298
#
#     accuracy                           0.81      1205
#    macro avg       0.76      0.68      0.70      1205
# weighted avg       0.79      0.81      0.79      1205

# %%
sns.heatmap(confusion_matrix(prediction1,y),annot=True)
# Out:
# <AxesSubplot:>

# %%
accuracy_score(prediction2,y)
# Out:
# 0.8448132780082988

# %%
sns.heatmap(confusion_matrix(prediction2,y),annot=True)
# Out:
# <AxesSubplot:>

# %%
confusion_matrix(prediction2,y)
# Out:
# array([[962, 129],
#        [ 58,  56]], dtype=int64)

# %%
from sklearn.neighbors import KNeighborsClassifier
K = KNeighborsClassifier()

# %%
K.fit(x,y)
# Out:
# KNeighborsClassifier()

# %%
prediction3 = K.predict(x)

# %%
accuracy_score(prediction3,y)
# Out:
# 0.8556016597510373

# %%
confusion_matrix(prediction3,y)
# Out:
# array([[1004,  158],
#        [  16,   27]], dtype=int64)

# %%
print(classification_report(prediction3,y))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.86      0.92      1162
#          1.0       0.15      0.63      0.24        43
#
#     accuracy                           0.86      1205
#    macro avg       0.57      0.75      0.58      1205
# weighted avg       0.95      0.86      0.90      1205

# %%
from sklearn.linear_model import LogisticRegression
L = LogisticRegression()

# %%
L.fit(x,y)
# Out:
# LogisticRegression()

# %%
prediction4 = L.predict(x)

# %%
confusion_matrix(prediction4,y)
# Out:
# array([[1018,  183],
#        [   2,    2]], dtype=int64)

# %%
accuracy_score(prediction4,y)
# Out:
# 0.8464730290456431

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
D=DecisionTreeClassifier()

# %%
D.fit(x,y)
#overfitting -> datanın çoğunu eğitime vermişiz / undercuting ->
# Out:
# DecisionTreeClassifier()

# %%
prediction5 = D.predict(x)

# %%
accuracy_score(prediction5,y)
# Out:
# 1.0

# %%
confusion_matrix(prediction5,y)
# Out:
# array([[1020,    0],
#        [   0,  185]], dtype=int64)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
R = RandomForestClassifier()

# %%
R.fit(x,y)
# Out:
# RandomForestClassifier()

# %%
prediction6 = R.predict(x)

# %%
accuracy_score(prediction6,y)
# Out:
# 1.0

# %%
confusion_matrix(prediction6,y)
# Out:
# array([[1020,    0],
#        [   0,  185]], dtype=int64)

# %%
from sklearn.ensemble import GradientBoostingClassifier
GB = GradientBoostingClassifier()

# %%
GB.fit(x,y)
# Out:
# GradientBoostingClassifier()

# %%
prediction7 = GB.predict(x)

# %%
accuracy_score(prediction7,y)
# Out:
# 0.9626556016597511

# %%
confusion_matrix(prediction7,y)
# Out:
# array([[1019,   44],
#        [   1,  141]], dtype=int64)

# %%
empty
# Out:
#       Age     BusinessTravel  DailyRate              Department  \
# 367    50      Travel_Rarely       1046  Research & Development
# 368    40      Travel_Rarely        575                   Sales
# 369    31      Travel_Rarely        408  Research & Development
# 370    21      Travel_Rarely        156                   Sales
# 371    29      Travel_Rarely       1283  Research & Development
# ...   ...                ...        ...                     ...
# 1461   50      Travel_Rarely        410                   Sales
# 1462   39      Travel_Rarely        722                   Sales
# 1463   31         Non-Travel        325  Research & Development
# 1464   26      Travel_Rarely       1167                   Sales
# 1465   36  Travel_Frequently        884  Research & Development
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  \
# 367                 10          3  Technical Degree              1
# ...

# %%
x = empty.drop("Attrition",axis=1)

# %%
x = pd.get_dummies(x,drop_first=True)

# %%
empty["Attrition"] = GB.predict(x)

# %%
empty.sample(6)
# Out:
#       Age     BusinessTravel  DailyRate              Department  \
# 1031   46      Travel_Rarely        377                   Sales
# 798    33      Travel_Rarely       1017  Research & Development
# 528    50  Travel_Frequently        562                   Sales
# 1269   43      Travel_Rarely        244         Human Resources
# 1006   49  Travel_Frequently       1475  Research & Development
# 1301   58         Non-Travel        350                   Sales
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  \
# 1031                 9          3         Marketing              1
# 798                 25          3           Medical              1
# 528                  8          2  Technical Degree              1
# 1269                 2          3     Life Sciences              1
# 1006                28          2     Life Sciences              1
# 1301                 2          3           Medical              1
#
# ...

# %%
dict = {0.0:"No",1.0:"Yes"}

# %%
empty["Attrition"] = empty["Attrition"].map(dict)

# %%
empty
# Out:
#       Age     BusinessTravel  DailyRate              Department  \
# 367    50      Travel_Rarely       1046  Research & Development
# 368    40      Travel_Rarely        575                   Sales
# 369    31      Travel_Rarely        408  Research & Development
# 370    21      Travel_Rarely        156                   Sales
# 371    29      Travel_Rarely       1283  Research & Development
# ...   ...                ...        ...                     ...
# 1461   50      Travel_Rarely        410                   Sales
# 1462   39      Travel_Rarely        722                   Sales
# 1463   31         Non-Travel        325  Research & Development
# 1464   26      Travel_Rarely       1167                   Sales
# 1465   36  Travel_Frequently        884  Research & Development
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  \
# 367                 10          3  Technical Degree              1
# ...

# %%
## Iris Data Set
import seaborn as sns

# %%
df = sns.load_dataset('iris')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.countplot(df["species"]);

# %%
sns.pairplot(df,hue="species");

# %%
from sklearn.svm import SVC

# %%
S = SVC()

# %%
x = df.drop("species",axis=1)
y=df["species"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.20,random_state=42)

# %%
pred = S.fit(x_train,y_train).predict(x_test)

# %%
confusion_matrix(y_test,pred)
# Out:
# array([[10,  0,  0],
#        [ 0,  9,  0],
#        [ 0,  0, 11]], dtype=int64)

# %%
accuracy_score(y_test,pred)
# Out:
# 1.0

# %%
df.shape
# Out:
# (150, 5)

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
S.predict([[5.1,3.5,1.4,0.2]])
# Out:
# array(['setosa'], dtype=object)
